# %% [markdown]
# # Lit-search-plotting-update
# 1.2.22
# Plotting the results of our mass spec imputation strategies literature search
#
# UPDATED 1.2.22. Now including citation counts from all of 2021 and all of 2022. Still just JPR.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

sns.set(context="talk", style="ticks") # plotting templates
sns.set_palette("tab10")

# %% [markdown]
# ### Create dataframe

# %%
# plotter = pd.DataFrame(columns=['method', 'counts'])
# plotter.method = ['low value sub', 'sample from normal dist.', 'mean/med value sub', 'zero value sub', 'RF', 'kNN', 'other']
# plotter.counts = [12, 22, 1, 1, 4, 4, 6]
# plotter

# %% [markdown]
# ### Plot

# %%
# # this one is ok...
# plt.figure(figsize=(6, 5))

# ax = sns.barplot(x="method", y="counts", data=plotter)
# ax.set_xlabel('')
# ax.set_ylabel('citation count')
# ax.set_title('Most commonly used imputation methods in JPR publications, 2019-2021', pad=20)

# ax.set_xticklabels(labels=list(plotter.method), rotation=30, ha='right')

# #plt.show()
# #plt.tight_layout()
# #plt.savefig('foobar.tif', dpi=250, bbox_inches="tight")

# %%
# # swap x and y, for increased readability
# ax = sns.barplot(x="counts", y="method", data=plotter)

# %% [markdown]
# ### The original plot

# %%
# lets try and make this more palatable
methods = ['mean value replacement', 'zero value replacement', 'Random Forest', 'k-Nearest Neighbors', 'other', 'low value replacement', 'sample from normal dist.']
counts = [1, 1, 4, 4, 6, 12, 22]

plotter_revis = pd.DataFrame(columns=['method', 'counts'])
plotter_revis.method = methods
plotter_revis.counts = counts
plotter_revis
# Out:
#                      method  counts
# 0    mean value replacement       1
# 1    zero value replacement       1
# 2             Random Forest       4
# 3       k-Nearest Neighbors       4
# 4                     other       6
# 5     low value replacement      12
# 6  sample from normal dist.      22

# %%
# I like this a LOT better
plt.figure(figsize=(6, 5))

ax = sns.barplot(x="counts", y="method", data=plotter_revis)
ax.set_xlabel('citation count')
ax.set_ylabel('')
#ax.set_title('Figure 1. Most commonly used imputation methods in\nJPR publications, 2019-2021', pad=40, fontsize=22)

plt.show()
#plt.tight_layout()
#plt.savefig('imp-lit-seq-results.png', dpi=250, bbox_inches="tight")

# %% [markdown]
# ### The updated plot

# %%
# lets try and make this more palatable
methods = [
        "MissForest", "Zero", "Mean",
        "Low value replacement", "Gaussian sample",
        "Double Boundary Bayes", "kNN", "MinProb",
        "Random forest", "Other"]

counts = [4, 2, 1, 15, 28, 2, 6, 2, 2, 4]

plotter_update = pd.DataFrame(columns=['method', 'counts'])
plotter_update.method = methods
plotter_update.counts = counts

# sort
plotter_update = plotter_update.sort_values(by="counts")

# plot
plt.figure(figsize=(6, 5))

ax = sns.barplot(x="counts", y="method", data=plotter_update)
ax.set_xlabel('Citation Count')
ax.set_ylabel('')

#plt.show()
#plt.tight_layout()
plt.savefig('imp-lit-seq-results-update1.png', dpi=250, bbox_inches="tight")
